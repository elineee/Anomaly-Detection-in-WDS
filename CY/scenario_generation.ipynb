# %% [markdown]
# # CY normal scenarios generation

# %%
import random
import math
import numpy as np
from epyt_flow.simulation import ScenarioSimulator, EpanetConstants


def create_random_contamination_event(time_window: tuple[int, int],
                                      duration_interval: tuple[int, int], n_time_steps: int):
    """Create a random contamination event profile for three contaminants:
    - Pathogen (P)
    - Carbon Fraction Rapidly Available (C_FRA)
    - Carbon Slowly Readily Available (C_SRA)
    The contamination event is defined by a random start time within the given time window
    and a random duration within the given duration interval.
    Args:
        time_window (tuple[int, int]): Time window (in time steps) within which the contamination event can start.
        duration_interval (tuple[int, int]): Duration interval (in time steps) for the contamination event.
        n_time_steps (int): Total number of time steps in the simulation.
    Returns:
        tuple: Three tuples, each containing the species ID and its corresponding contamination profile (mass injected at each time step).
    """
    # Random point in time
    start_time = random.randint(time_window[0], time_window[1])

    # Random duration
    end_time = start_time + random.randint(duration_interval[0], duration_interval[1])
    
    print("start end", start_time, end_time)

    # Random amount of contaminants (no need to change these values)
    EV_log_min = math.log10(1.39e6)
    EV_log_max = math.log10(2.08e7)
    EV_conc = 10 ** (EV_log_min + random.uniform(0, 1) * (EV_log_max - EV_log_min))
    TOC = 140 + random.uniform(0, 1) * (250 - 140)
    C_FRA_fraction = 0.4
    C_SRA_fraction = 0.6

    rates = [10, 20, 50, 100, 200, 500] # possible injection intensities (in mass per minute)
    rate = random.choice(rates) # injection intensity

    injection_conc_P = EV_conc * rate 

    injection_conc_C_FRA = C_FRA_fraction * TOC * rate
    injection_conc_C_SRA = C_SRA_fraction * TOC * rate
    print(injection_conc_P, injection_conc_C_FRA, injection_conc_C_SRA)

    # Initialize profiles with zeros (no contamination at the beginning)
    # Then add the contamination event for the corresponding time steps

    profile_P = np.zeros(n_time_steps)
    profile_P[start_time:end_time] = injection_conc_P 

    profile_C_FRA = np.zeros(n_time_steps)
    profile_C_FRA[start_time:end_time] = injection_conc_C_FRA

    profile_C_SRA = np.zeros(n_time_steps)
    profile_C_SRA[start_time:end_time] = injection_conc_C_SRA

    # return lists of values for each time step, for each species that correspond to what we will inject at each time step, for each species
    return ("P", profile_P), ("C_FRA", profile_C_FRA), ("C_SRA", profile_C_SRA)

# %% [markdown]
# Set parameters and files for simulation

# %%
number = 7 # number of the msx files (corresponds to specific conditions, such as a specific demand pattern)

f_inp_in = "CY-DBP_competition_stream_competition_6days_" + str(number) + ".inp"
f_msx_in = "CY-DBP_competition_stream_competition_6days_" + str(number) + ".msx"

########################################################################
# Parameters of the contamination events
duration_interval = (500, 1000)    # Duration interval of the contamination event in minutes 
n_contamination_events = 1  # Number of contamination events to generate
time_window = (4, 7)        # Event can start between day 4 and day 7
########################################################################

# %% [markdown]
# Create the scenario

# %%
scenario = ScenarioSimulator(f_inp_in=f_inp_in, f_msx_in=f_msx_in)

# %% [markdown]
# Explore the network :

# %%
from epyt_flow.visualization import ScenarioVisualizer
vis = ScenarioVisualizer(scenario)
vis.add_labels(["nodes"])
vis.show_plot(export_to_file="cy_nodes.pdf")

# %%
topo = scenario.get_topology()

print(topo.nodes)
print(topo.edges)
# Out:
# ['distTreatbefore', 'distTreatafter', 'distafterTank', 'dist1', 'dist11', 'dist30', 'dist33', 'dist35', 'dist51', 'dist64', 'dist66', 'dist68', 'dist71', 'dist78', 'dist83', 'dist90', 'dist97', 'dist100', 'dist103', 'dist105', 'dist106', 'dist110', 'dist115', 'dist116', 'dist136', 'dist160', 'dist165', 'dist179', 'dist181', 'dist183', 'dist195', 'dist209', 'dist219', 'dist223', 'dist225', 'dist231', 'dist273', 'dist275', 'dist284', 'dist288', 'dist289', 'dist295', 'dist306', 'dist310', 'dist312', 'dist330', 'dist337', 'dist341', 'dist342', 'dist348', 'dist354', 'dist356', 'dist361', 'dist376', 'dist379', 'dist383', 'dist394', 'dist398', 'dist399', 'dist406', 'dist408', 'dist412', 'dist412_new', 'dist415', 'dist417', 'dist420', 'dist423', 'dist424', 'dist426', 'dist439', 'dist443', 'dist446', 'dist458', 'dist470', 'dist473', 'dist485', 'dist490', 'dist494', 'dist504', 'dist521', 'dist523', 'dist525', 'dist532', 'dist546', 'dist555', 'dist559', 'dist585', 'dist592', 'dist593', 'dist606', 'dist616', 'dist622', 'dist628', 'dist631', 'dist632', 'dist648', 'dist650', 'dist655', 'dist656', 'dist679', 'dist680', 'dist681', 'dist688', 'dist701', 'dist707', 'dist708', 'dist745', 'dist759', 'dist772', 'dist787', 'dist789', 'dist806', 'dist819', 'dist830', 'dist839', 'dist852', 'dist865', 'dist885', 'dist889', 'dist891', 'dist896', 'dist908', 'dist931', 'dist932', 'dist989', 'dist993', 'dist996', 'dist998', 'dist999', 'dist1001', 'dist1003', 'dist1020', 'dist1025', 'dist1028', 'dist1031', 'dist1039', 'dist1075', 'dist1081', 'dist1126', 'dist1130', 'dist1144', 'dist1155', 'dist1165', 'dist1168', 'dist1179', 'dist1185', 'dist1196', 'dist1202', 'dist1214', 'dist1225', 'dist1226', 'dist1229', 'dist1241', 'dist1245', 'dist1252', 'dist1255', 'dist1268', 'dist1272', 'dist1283', 'dist1284', 'dist1287', 'dist1292', 'dist1294', 'dist1303', 'dist1304', 'dist1308', 'dist1309', 'dist1311', 'dist1313', 'dist1332', 'dist1339', 'dist1343', 'dist1345', 'dist1346', 'dist1363', 'dist1367', 'dist1369', 'dist1371', 'dist1372', 'dist1406', 'dist1413', 'dist1443', 'dist1446', 'dist1454', 'dist1455', 'dist1459', 'dist1464', 'dist1468', 'dist1471', 'dist1472', 'dist1496', 'dist1499', 'dist1502', 'dist1511', 'dist1522', 'dist1528', 'dist1539', 'dist1550', 'dist1557', 'dist1568', 'dist1607', 'dist1608', 'dist1611', 'dist1622', 'dist1634', 'dist1636', 'dist1656', 'dist1687', 'dist1689', 'dist1694', 'dist1702', 'dist1722', 'dist1723', 'dist1740', 'dist1741', 'dist1765', 'dist1768', 'dist1769', 'dist1770', 'dist1786', 'dist1788', 'dist1801', 'dist1802', 'dist1808', 'dist1812', 'dist1829', 'dist1840', 'dist1843', 'dist1850', 'dist1854', 'dist1869', 'dist1876', 'dist1877', 'dist1878', 'dist1887', 'dist1892', 'dist1893', 'dist1900', 'dist1901', 'dist1903', 'dist1906', 'dist1915', 'dist1924', 'dist1931', 'dist1936', 'dist1944', 'dist1962', 'dist1973', 'dist1975', 'dist1978', 'dist1979', 'dist1984', 'dist1987', 'dist1988', 'distother_zones', 'distother_dmas', 'WTP', 'T_Zone']
# [('distTreatbefore', 'WTP'), ('distTreatbefore', 'distTreatafter'), ('distTreatafter', 'T_Zone'), ('distafterTank', 'T_Zone'), ('distafterTank', 'distother_dmas'), ('distafterTank', 'dist423'), ('dist1', 'dist11'), ('dist1', 'dist106'), ('dist11', 'dist35'), ('dist11', 'dist30'), ('dist30', 'dist116'), ('dist33', 'dist35'), ('dist33', 'dist71'), ('dist33', 'dist51'), ('dist35', 'dist64'), ('dist51', 'dist103'), ('dist51', 'dist68'), ('dist66', 'dist273'), ('dist66', 'dist105'), ('dist68', 'dist284'), ('dist68', 'dist195'), ('dist71', 'dist103'), ('dist71', 'dist90'), ('dist78', 'dist83'), ('dist83', 'dist97'), ('dist83', 'dist312'), ('dist97', 'dist110'), ('dist97', 'dist341'), ('dist100', 'dist183'), ('dist103', 'dist181'), ('dist106', 'dist348'), ('dist106', 'dist306'), ('dist110', 'dist115'), ('dist110', 'dist165'), ('dist116', 'dist160'), ('dist116', 'dist225'), ('dist136', 'dist179'), ('dist160', 'dist181'), ('dist160', 'dist310'), ('dist165', 'dist219'), ('dist165', 'dist379'), ('dist179', 'dist223'), ('dist179', 'dist273'), ('dist181', 'dist288'), ('dist183', 'dist275'), ('dist183', 'dist231'), ('dist195', 'dist209'), ('dist195', 'dist348'), ('dist219', 'dist424'), ('dist223', 'dist231'), ('dist223', 'dist342'), ('dist225', 'dist330'), ('dist225', 'dist289'), ('dist231', 'dist275'), ('dist273', 'dist342'), ('dist275', 'dist312'), ('dist284', 'dist394'), ('dist284', 'dist288'), ('dist288', 'dist295'), ('dist289', 'dist420'), ('dist289', 'dist383'), ('dist295', 'dist399'), ('dist295', 'dist310'), ('dist306', 'dist356'), ('dist310', 'dist330'), ('dist312', 'dist341'), ('dist330', 'dist417'), ('dist337', 'dist376'), ('dist341', 'dist354'), ('dist342', 'dist412'), ('dist348', 'dist394'), ('dist354', 'dist379'), ('dist354', 'dist559'), ('dist356', 'dist376'), ('dist356', 'dist361'), ('dist376', 'dist398'), ('dist376', 'dist415'), ('dist379', 'dist408'), ('dist383', 'dist446'), ('dist394', 'dist426'), ('dist398', 'dist1028'), ('dist398', 'dist406'), ('dist399', 'dist426'), ('dist399', 'dist504'), ('dist408', 'dist439'), ('dist408', 'dist490'), ('dist412', 'dist458'), ('dist412', 'dist412_new'), ('dist412_new', 'dist622'), ('dist415', 'dist470'), ('dist415', 'dist473'), ('dist417', 'dist504'), ('dist417', 'dist443'), ('dist420', 'dist458'), ('dist420', 'dist525'), ('dist423', 'dist1268'), ('dist424', 'dist439'), ('dist426', 'dist485'), ('dist439', 'dist521'), ('dist443', 'dist446'), ('dist443', 'dist648'), ('dist446', 'dist523'), ('dist458', 'dist680'), ('dist470', 'dist485'), ('dist470', 'dist632'), ('dist473', 'dist555'), ('dist473', 'dist606'), ('dist485', 'dist494'), ('dist490', 'dist585'), ('dist490', 'dist521'), ('dist494', 'dist996'), ('dist494', 'dist532'), ('dist504', 'dist592'), ('dist521', 'dist616'), ('dist523', 'dist525'), ('dist523', 'dist648'), ('dist532', 'dist546'), ('dist532', 'dist1001'), ('dist546', 'dist592'), ('dist546', 'dist1020'), ('dist555', 'dist688'), ('dist555', 'dist628'), ('dist559', 'dist593'), ('dist559', 'dist655'), ('dist585', 'dist593'), ('dist585', 'dist616'), ('dist592', 'dist631'), ('dist593', 'dist681'), ('dist606', 'dist759'), ('dist606', 'dist632'), ('dist616', 'dist789'), ('dist622', 'dist819'), ('dist622', 'dist650'), ('dist631', 'dist707'), ('dist631', 'dist679'), ('dist632', 'dist1039'), ('dist648', 'dist680'), ('dist650', 'dist655'), ('dist655', 'dist656'), ('dist656', 'dist891'), ('dist656', 'dist681'), ('dist679', 'dist708'), ('dist679', 'dist889'), ('dist680', 'dist787'), ('dist681', 'dist891'), ('dist701', 'dist759'), ('dist707', 'dist745'), ('dist707', 'dist1031'), ('dist708', 'dist806'), ('dist708', 'dist787'), ('dist745', 'dist772'), ('dist745', 'dist889'), ('dist759', 'dist865'), ('dist787', 'dist852'), ('dist789', 'dist989'), ('dist789', 'dist931'), ('dist806', 'dist830'), ('dist806', 'dist1031'), ('dist819', 'dist852'), ('dist830', 'dist993'), ('dist830', 'dist896'), ('dist839', 'dist889'), ('dist852', 'dist885'), ('dist865', 'dist932'), ('dist885', 'dist908'), ('dist885' ...

# %%
# Show information associated with node "dist1308"
print(topo.get_node_info("dist1308"))
# Out:
# {'elevation': 57.223899841308594, 'coord': [950.0, 1190.0], 'comment': 'NULL', 'type': 0, 'base_demand': 0.17833499610424042}

# %%
from epyt_flow.utils import to_seconds
# set the simulation duration 
scenario.set_general_parameters(simulation_duration=to_seconds(days=9))

# %% [markdown]
# Inject contamination event

# %%
# Setup time intervals
hyd_time_step = scenario.get_hydraulic_time_step()  # Usually 5min time steps (so 5*60 seconds )
steps_per_day = (24 * 60 * 60) / hyd_time_step
time_window = (time_window[0] * steps_per_day, time_window[1] * steps_per_day) 
duration_interval = ((duration_interval[0] * 60) / hyd_time_step,
                        (duration_interval[1] * 60) / hyd_time_step)
n_time_steps = int(scenario.get_simulation_duration() / hyd_time_step)

# Add random contamination events
all_junctions = scenario.get_topology().get_all_junctions() # get all nodes in the network
contamination_patterns = [] 
for _ in range(n_contamination_events):
    node_id = "dist423"
    print(f"Injecting contamination at node {node_id}")
    contaminants_profiles = create_random_contamination_event(time_window, duration_interval,
                                                                n_time_steps) # get contamination profiles for each species
    print(time_window, duration_interval, n_time_steps)
    for species_id, pattern in contaminants_profiles:
        contamination_patterns.append(pattern) # pattern is the list of values at each time step for each species
        scenario.add_species_injection_source(species_id, node_id, pattern, EpanetConstants.EN_MASS) # inject contamination into the node following the profile
# Out:
# Injecting contamination at node dist423
# start end 1493 1614
# 48002243.823693395 791.9998195286753 1187.999729293013
# (1152.0, 2016.0) (100.0, 200.0) 2592

# %% [markdown]
# Check the moment of the contamination

# %%
# Compute labels for each time step
# 1 if a contamination present, 0 otherwise
y = np.sum(contamination_patterns, axis=0) != 0
print(y.shape)  # TODO: Export 
# number of time steps with contamination
print(f"Number of time steps with contamination: {np.sum(y)} out of {len(y)}")
# start time steps of contamination events
for i in range(1, len(y)):
    if y[i] != 0 and y[i-1] == 0:
        print(f"Contamination event starts at time step {i}")
# Out:
# (2592,)
# Number of time steps with contamination: 121 out of 2592
# Contamination event starts at time step 1493

# %% [markdown]
# Run simulation

# %%
# TEST: run simulation
# Place sensors at all nodes 
scenario.place_bulk_species_node_sensors_everywhere(["P", "CL2", "C_FRA","C_SRA" ]) # Measure of pathogen and chlorine. Chlorine is used as a proxy to detect contamination 
# Run hydraulic and water quality simulation
scada_data = scenario.run_simulation(verbose=True)
# Out:
# Running EPANET ...
# Time steps:   0%|          | 0/2593 [00:00<?, ?it/s]
# Time steps: 100%|#########9| 2592/2593 [00:07<00:00, 343.57it/s]
# Running EPANET-MSX ...
# Time steps: 100%|#########9| 2592/2593 [00:24<00:00, 104.31it/s]
# c:\Users\eline\Documents\Documents\university\Master 2\memoire\AI-for-Drinking-Water\env\Lib\site-packages\epyt_flow\simulation\scenario_simulator.py:2978: UserWarning: Failed to remove temporary file 'C:\Users\eline\AppData\Local\Temp\epytflow_MSX_38e44c64-c058-4d4a-99c4-2b954f6e059d.hyd'
#   warnings.warn(f"Failed to remove temporary file '{hyd_export}'")

# %% [markdown]
# Plot Scada Data :

# %%
# Plot chlorine concentration at specific nodes
scada_data.plot_bulk_species_node_concentration({"CL2": [node_id]})
scada_data.plot_bulk_species_node_concentration({"CL2": ["dist90"]}) 
scada_data.plot_bulk_species_node_concentration({"CL2": ["dist1214"]})
# Out:
# <Axes: xlabel='Time (5min steps)', ylabel='Concentration in $MG/L$'>

# %%
# Plot pathogen concentration at specific nodes
scada_data.plot_bulk_species_node_concentration({"P": [node_id]}) 
scada_data.plot_bulk_species_node_concentration({"P": ["dist30"]}) 
scada_data.plot_bulk_species_node_concentration({"P": ["dist106"]})
# Out:
# <Axes: xlabel='Time (5min steps)', ylabel='Concentration in $CUSTOM UNIT/L$'>

# %%
scada_data.plot_bulk_species_node_concentration({"C_SRA": [node_id]})
scada_data.plot_bulk_species_node_concentration({"C_SRA": ["dist11"]}) 
scada_data.plot_bulk_species_node_concentration({"C_SRA": ["dist33"]}) 
scada_data.plot_bulk_species_node_concentration({"C_SRA": ["dist64"]})
# Out:
# <Axes: xlabel='Time (5min steps)', ylabel='Concentration in $MG/L$'>

# %%
scada_data.plot_bulk_species_node_concentration({"C_FRA": [node_id]})
scada_data.plot_bulk_species_node_concentration({"C_FRA": ["dist11"]}) 
scada_data.plot_bulk_species_node_concentration({"C_FRA": ["dist33"]}) 
scada_data.plot_bulk_species_node_concentration({"C_FRA": ["dist64"]})
# Out:
# <Axes: xlabel='Time (5min steps)', ylabel='Concentration in $MG/L$'>

# %% [markdown]
# Export Scada Data to csv

# %%
import pandas as pd
df = scada_data.to_pandas_dataframe(export_raw_data=False)

for column in df.columns:
    if "[CUSTOM UNIT]" in column:
        new_column_name = column.replace("[CUSTOM UNIT]", "[MG]")
        df.rename(columns={column: new_column_name}, inplace=True)
    if "CL2" in column:
        new_column_name = column.replace("CL2", "Chlorine")
        df.rename(columns={column: new_column_name}, inplace=True)

df.to_csv(f"scada_data_test_{number}.csv", index=False)

# %%
scenario.close()
